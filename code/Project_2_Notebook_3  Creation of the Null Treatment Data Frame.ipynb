# %% [markdown]
# # Project 2 - Ames Housing Data and Kaggle Challenge
# ## Notebook 3/4: Creation of the Null Treatment Data Frame
#
# #### Kristina Joos
#
# Notebook 1: Cleaning and Modfications of Train Data.
# Notebook 2: Cleaning and Modfications of Test Data.
# Notebook 3: Creation of the Null Treatment Data Frame.
# Notebook 4: Modeling and Predictions.

# %% [markdown]
# ### 3.1 Importing libraries
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# ### 3.2 Importing data
# ---

# %%
train_df = pd.read_csv("../data/train.csv")
test_df = pd.read_csv("../data/test.csv")

# %%
train_df.rename(columns = lambda x: x.lower().replace(' ','_'), inplace = True)

# %% [markdown]
# ### 3.3 Creating Null Value DataFrame null_train_df
# ---

# %%
train_df.isnull().mean()[train_df.isnull().mean() > 0].sort_values(
                                                ascending=False)
# Out:
# pool_qc           0.995612
# misc_feature      0.968308
# alley             0.931741
# fence             0.804973
# fireplace_qu      0.487567
# lot_frontage      0.160897
# garage_yr_blt     0.055583
# garage_cond       0.055583
# garage_qual       0.055583
# garage_finish     0.055583
# garage_type       0.055095
# bsmt_exposure     0.028279
# bsmtfin_type_2    0.027304
# bsmt_cond         0.026816
# bsmt_qual         0.026816
# bsmtfin_type_1    0.026816
# mas_vnr_type      0.010726
# mas_vnr_area      0.010726
# bsmt_half_bath    0.000975
# bsmt_full_bath    0.000975
# garage_cars       0.000488
# bsmtfin_sf_1      0.000488
# bsmtfin_sf_2      0.000488
# bsmt_unf_sf       0.000488
# garage_area       0.000488
# total_bsmt_sf     0.000488
# dtype: float64

# %%
null_train_df = pd.DataFrame(data = train_df.isnull().sum()[train_df.isnull().sum() > 0].sort_values(
                                                ascending=False) , columns = ['sum'])

# %%
null_train_df['mean']=train_df.isnull().sum()[train_df.isnull().mean() > 0].sort_values(
                                                ascending=False)

# %%
null_train_df['first_row_value'] = train_df.loc[1,['pool_qc', 'misc_feature', 'alley', 'fence', 'fireplace_qu',
       'lot_frontage', 'garage_yr_blt', 'garage_cond', 'garage_qual',
       'garage_finish', 'garage_type', 'bsmt_exposure', 'bsmtfin_type_2',
       'bsmt_cond', 'bsmt_qual', 'bsmtfin_type_1', 'mas_vnr_type',
       'mas_vnr_area', 'bsmt_half_bath', 'bsmt_full_bath', 'garage_cars',
       'bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'garage_area',
       'total_bsmt_sf']]

# %%
description = ['Pool Quality (Ex, Gd, TA, Fa, NA (No Pool))',
                'Miscellaneous feature not covered in other categories (Elev, Gar2, Othr, Shed, TenC, NA (None))',
                'Type of alley access to property (Grvl, Pave, NA (No alley access))',
                'Fence quality (GdPrv (Good Privacy), MnPrv (Minimum Privacy),GdWo (Good Wood), MnWw (Minimum Wood/Wire), NA (No Fence))',
                'Fireplace quality (Ex, Gd, TA, Fa, Po, NA (No Fireplace))',
                'Linear feet of street connected to property',
                'Year garage was built',
                'Garage condition (Ex, Gd, TA, Fa, Po, NA (No Garage))',
                'Garage quality (Ex, Gd, TA, Fa, Po, NA (No Garage))',
                'Interior finish of the garage (Fin (Finished), RFn (Rough Finished), Unf (Unfinished), NA (No Garage))',
                'Garage location (2Types, Attchd, Basment, BuiltIn, CarPort, Detchd, NA (No Garage))',
                'Refers to walkout or garden level walls (Gd, Av, Mn, No, NA)',
                'Rating of basement finished area (if multiple types)(GLQ, ALQ, BLQ, Rec, LwQ, Unf, NA (No Basement)',
                'Evaluates the general condition of the basement (Ex, Gd, TA, Fa, Po, NA (No Basement))',
                'Evaluates the height of the basement (Ex(100+ inches),Gd (90-99 inches),TA (80-89 inches),Fa (70-79 inches), Po (<70 inches), NA (No Basement)',
                'Rating of basement finished area (GLQ, ALQ, BLQ, Rec, LwQ, Unf, NA (No Basement))',
                'Masonry veneer type (BrkCmn, BrkFace, CBlock, None, Stone)',
                'Masonry veneer area in square feet',
                'Basement half bathrooms (Discrete)',
                'Basement full bathrooms (Discrete)',
                'Size of garage in car capacity (Discrete)',
                'Type 1 finished square feet (Continuos)',
                'Type 2 finished square feet (Continuos)',
                'Unfinished square feet of basement area (Continuos)',
                'Size of garage in square feet (Continuos)',
                'Total square feet of basement area (Continuos)']

# %%
null_train_df['feature_description'] = description

# %%
treatment = ['Fill NaN with None', 
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
            'Fill NaN with median lot frontage in neighborhood',
            'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill NaN with None',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
             'Fill with float 0,0',
            'Fill with float 0,0']

# %%
 pd.options.display.max_rows = 4000

# %%
null_train_df.shape
# Out:
# (26, 4)

# %%
len(treatment)
# Out:
# 26

# %%
null_train_df['treatment'] = treatment

# %%
null_train_df
# Out:
#                  sum  mean first_row_value  \
# pool_qc         2042  2042             NaN
# misc_feature    1986  1986             NaN
# alley           1911  1911             NaN
# fence           1651  1651             NaN
# fireplace_qu    1000  1000              TA
# lot_frontage     330   330              43
# garage_yr_blt    114   114            1997
# garage_cond      114   114              TA
# garage_qual      114   114              TA
# garage_finish    114   114             RFn
# garage_type      113   113          Attchd
# bsmt_exposure     58    58              No
# bsmtfin_type_2    56    56             Unf
# bsmt_cond         55    55              TA
# bsmt_qual         55    55              Gd
# bsmtfin_type_1    55    55             GLQ
# mas_vnr_type      22    22         BrkFace
# mas_vnr_area      22    22             132
# bsmt_half_bath     2     2               0
# bsmt_full_bath     2     2               1
# garage_cars        1     1               2
# ...

# %%
null_train_df.to_csv(r'.\nulltrain.csv')
